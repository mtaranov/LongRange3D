# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import sys
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import copy
sys.path.append('/users/mtaranov/LongRange3D/')
from models_motif import LongRangeDNN_FC
from utils import  concat_motifs,get_features, get_labels, subsample_data, normalize_features, reconstruct_2d, printMatrix, binarize, zscore, get_2D, plot_prediction, change_scale 
#from sklearn.preprocessing import MinMaxScaler, StandardScaler
#from dragonn.models import Model, SequenceDNN
#from keras.models import Sequential
#from keras.callbacks import Callback, EarlyStopping
#from keras.layers.core import (
#    Activation, Dense, Dropout, Flatten,
#    Permute, Reshape, TimeDistributedDense
#)
#from keras.layers.convolutional import Convolution2D, MaxPooling2D
#from keras.layers.recurrent import GRU
#from keras.regularizers import l1

#from deeplift import keras_conversion as kc
#from deeplift.blobs import MxtsMode
# Out:
# Using Theano backend.
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is enabled with initial size: 2500 MB, cuDNN 5105)

# %%
contacts='PE'
path='/users/mtaranov/datasets_3d/dist_matched_'+contacts+'/'

X_train = np.load(path+'motifs/train_'+contacts+'_out_btw_nodes_3_0.0001/mat.npy')
X_test = np.load(path+'motifs/test_'+contacts+'_out_btw_nodes_3_0.0001/mat.npy')
X_valid = np.load(path+'motifs/valid_'+contacts+'_out_btw_nodes_3_0.0001/mat.npy')

y_train = get_labels(path+'y_train_thres_10.npy')
y_test = get_labels(path+'y_test_thres_10.npy')
y_valid = get_labels(path+'y_valid_thres_10.npy')

# %%
X_train.shape, X_test.shape, X_valid.shape
# Out:
# ((4824, 1920), (1812, 1920), (2872, 1920))

# %%
def normalize_features(X_train, X_valid, X_test, normalizer=StandardScaler):
    # fit normalizer
    normalizer = normalizer().fit(X_train[:,:])
    # transform features
    X_train_new=copy.copy(X_train)
    X_valid_new=copy.copy(X_valid)
    X_test_new=copy.copy(X_test)
    X_train_new = normalizer.transform(X_train)
    X_valid_new = normalizer.transform(X_valid)
    X_test_new = normalizer.transform(X_test)

    return (X_train_new, X_valid_new, X_test_new)

# %%
X_train_normalized, X_valid_normalized, X_test_normalized = normalize_features(X_train, X_valid, X_test)

#X_train_normalized_subsampled, y_train_subsampled = subsample_data(X_train_normalized, y_train)
#X_valid_normalized_subsampled, y_valid_subsampled = subsample_data(X_valid_normalized, y_valid)
#X_test_normalized_subsampled, y_test_subsampled = subsample_data(X_test_normalized, y_test)

#X_train_scaled_subsampled, y_train_subsampled = subsample_data(X_train_scaled, y_train)
#X_valid_scaled_subsampled, y_valid_subsampled = subsample_data(X_valid_scaled, y_valid)
#X_test_scaled_subsampled, y_test_subsampled = subsample_data(X_test_scaled, y_test)

# %%
from models_motif import LongRangeDNN_FC
dnn_normalized = LongRangeDNN_FC(num_features=1920, use_deep_CNN=False)
validation_data = (X_valid_normalized, y_valid)
dnn_normalized.train(X_train_normalized, y_train, validation_data)
# Out:
# Training model...
# Train on 4824 samples, validate on 2872 samples
# Epoch 1/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 3.9338Epoch 0: validation loss: 0.702
# Balanced Accuracy: 69.15%	 auROC: 0.749	 auPRC: 0.740	 auPRG: 0.507
# Recall at 5%|10%|20% FDR: 0.1%|0.1%|43.7%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 1s - loss: 3.9058 - val_loss: 0.7016
# Epoch 2/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 1.2561Epoch 1: validation loss: 0.537
# Balanced Accuracy: 75.45%	 auROC: 0.833	 auPRC: 0.833	 auPRG: 0.698
# Recall at 5%|10%|20% FDR: 0.3%|43.7%|69.6%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 1s - loss: 1.2495 - val_loss: 0.5365
# Epoch 3/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 0.6204Epoch 2: validation loss: 0.448
# Balanced Accuracy: 80.26%	 auROC: 0.883	 auPRC: 0.891	 auPRG: 0.802
# Recall at 5%|10%|20% FDR: 47.4%|62.4%|80.2%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 1s - loss: 0.6168 - val_loss: 0.4480
# Epoch 4/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 0.4020Epoch 3: validation loss: 0.428
# Balanced Accuracy: 81.44%	 auROC: 0.896	 auPRC: 0.901	 auPRG: 0.830
# Recall at 5%|10%|20% FDR: 51.8%|68.2%|83.9%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 1s - loss: 0.4009 - val_loss: 0.4281
# Epoch 5/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 0.2876Epoch 4: validation loss: 0.417
# Balanced Accuracy: 82.73%	 auROC: 0.901	 auPRC: 0.903	 auPRG: 0.840
# Recall at 5%|10%|20% FDR: 50.5%|70.2%|85.6%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 1s - loss: 0.2871 - val_loss: 0.4166
# Epoch 6/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 0.2099Epoch 5: validation loss: 0.405
# Balanced Accuracy: 83.25%	 auROC: 0.908	 auPRC: 0.912	 auPRG: 0.855
# Recall at 5%|10%|20% FDR: 60.1%|73.2%|87.5%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 1s - loss: 0.2103 - val_loss: 0.4045
# Epoch 7/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 0.1583Epoch 6: validation loss: 0.407
# Balanced Accuracy: 83.32%	 auROC: 0.911	 auPRC: 0.915	 auPRG: 0.861
# Recall at 5%|10%|20% FDR: 60.1%|74.7%|87.8%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 1s - loss: 0.1582 - val_loss: 0.4070
# Epoch 8/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 0.1207Epoch 7: validation loss: 0.403
# Balanced Accuracy: 84.58%	 auROC: 0.918	 auPRC: 0.922	 auPRG: 0.879
# Recall at 5%|10%|20% FDR: 68.2%|79.6%|88.1%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 1s - loss: 0.0085 - val_loss: 0.4996
# Epoch 24/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 0.0075Epoch 23: validation loss: 0.510
# Balanced Accuracy: 84.44%	 auROC: 0.917	 auPRC: 0.921	 auPRG: 0.879
# Recall at 5%|10%|20% FDR: 68.2%|79.2%|88.1%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 1s - loss: 0.0075 - val_loss: 0.5098
# Epoch 25/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 0.0067Epoch 24: validation loss: 0.512
# Balanced Accuracy: 84.54%	 auROC: 0.918	 auPRC: 0.924	 auPRG: 0.879
# Recall at 5%|10%|20% FDR: 67.3%|79.3%|87.9%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 1s - loss: 0.0067 - val_loss: 0.5124
# Epoch 26/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 0.0062Epoch 25: validation loss: 0.522
# Balanced Accuracy: 84.54%	 auROC: 0.917	 auPRC: 0.922	 auPRG: 0.878
# Recall at 5%|10%|20% FDR: 67.6%|79.4%|88.2%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 1s - loss: 0.0062 - val_loss: 0.5220
# Epoch 27/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 0.0054Epoch 26: validation loss: 0.532
# Balanced Accuracy: 84.40%	 auROC: 0.917	 auPRC: 0.922	 auPRG: 0.878
# Recall at 5%|10%|20% FDR: 67.2%|79.6%|88.0%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 1s - loss: 0.0054 - val_loss: 0.5315
# Epoch 28/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 0.0048Epoch 27: validation loss: 0.538
# Balanced Accuracy: 84.58%	 auROC: 0.917	 auPRC: 0.921	 auPRG: 0.878
# Recall at 5%|10%|20% FDR: 67.8%|79.6%|88.1%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 1s - loss: 0.0048 - val_loss: 0.5380
# Epoch 29/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 0.0044Epoch 28: validation loss: 0.543
# Balanced Accuracy: 84.40%	 auROC: 0.917	 auPRC: 0.922	 auPRG: 0.878
# Recall at 5%|10%|20% FDR: 67.6%|79.3%|87.9%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 1s - loss: 0.0044 - val_loss: 0.5431

# %%
print(dnn_normalized.test(X_test_normalized, y_test))
print(dnn_normalized.test(X_train_normalized, y_train))
print(dnn_normalized.test(X_valid_normalized, y_valid))
# Out:
# Balanced Accuracy: 84.33%	 auROC: 0.907	 auPRC: 0.910	 auPRG: 0.861
# Recall at 5%|10%|20% FDR: 61.3%|78.1%|87.4%	 Num Positives: 906	 Num Negatives: 906
# Balanced Accuracy: 100.00%	 auROC: 1.000	 auPRC: 1.000	 auPRG: 1.000
# Recall at 5%|10%|20% FDR: 100.0%|100.0%|100.0%	 Num Positives: 2412	 Num Negatives: 2412
# Balanced Accuracy: 84.40%	 auROC: 0.917	 auPRC: 0.922	 auPRG: 0.878
# Recall at 5%|10%|20% FDR: 67.6%|79.3%|87.9%	 Num Positives: 1436	 Num Negatives: 1436

# %%
#save model and weights
dnn_normalized.save(contacts+'_dnn_FC_Window_motifs', '/users/mtaranov/LongRange3D/')

# %% [markdown]
# # DeepLift

# %%
weights='/users/mtaranov/LongRange3D/weights/'+contacts+'_dnn_FC_Window_motifs.weights.h5'
json_model='/users/mtaranov/LongRange3D/models/'+contacts+'_dnn_FC_Window_motifs.arch.json'

# %%
scores = dnn_normalized.deeplift(X_valid_normalized, weights, json_model, batch_size=128)
# Out:
# nonlinear_mxts_mode is set to: Gradient

# %%
np.save('/users/mtaranov/LongRange3D/deeplift_scores/'+contacts+'_scores_dnn_FC_Window_motifs.npy', scores)

# %%
scores.shape
# Out:
# (2872, 1920)

# %%
plt.plot(np.mean(scores[10:,:], axis=0))

# %%
plt.pcolor(scores[10:,:], cmap='hot', vmin=np.min(scores[10:,:]), vmax=np.max(scores[10:,:])) # cmap='RdBu'
plt.xlabel('motifs/features')
plt.ylabel('examples')
plt.title('DeepLift Score - Window Motifs')
plt.colorbar()

# %%
motif_names=np.loadtxt('/users/mtaranov/datasets_3d/dist_matched_PE/motifs/train_PE_out_btw_nodes_3_0.0001/motif_names.txt', dtype=str, delimiter='/')[:,6:].reshape(640,)
top_3_hits_names=[]
for i in motif_names:
    for j in range(3):
        top_3_hits_names.append(i)
top_3_hits_names = np.array(top_3_hits_names)

# %%
sorted(top_3_hits_names[np.where(np.mean(scores[10:,:], axis=0)>0.03)])
# Out:
# ['BHE23_HUMAN',
#  'FOXG1_HUMAN',
#  'FOXL1_HUMAN',
#  'FOXO3_HUMAN',
#  'FOXO6_HUMAN',
#  'GLI1_HUMAN',
#  'HAND1_HUMAN',
#  'MYC_HUMAN',
#  'NFIA_HUMAN',
#  'NR1I2_HUMAN',
#  'NR2E3_HUMAN',
#  'NR4A1_HUMAN',
#  'PPARG_HUMAN',
#  'PTF1A_HUMAN',
#  'PURA_HUMAN',
#  'RARG_HUMAN',
#  'SCRT1_HUMAN',
#  'SCRT2_HUMAN',
#  'SNAI2_HUMAN',
#  'SOX18_HUMAN',
#  'SPIC_HUMAN',
#  'TBX1_HUMAN',
#  'TBX1_HUMAN',
#  'TEAD1_HUMAN',
#  'TGIF1_HUMAN',
#  'TWST1_HUMAN',
#  'TYY1_HUMAN',
#  'UBIP1_HUMAN',
#  'UBIP1_HUMAN',
#  'ZBT7A_HUMAN',
#  'ZN143_HUMAN',
#  'ZN143_HUMAN',
#  'ZN143_HUMAN',
#  'ZN410_HUMAN',
#  'ZN713_HUMAN',
#  'ZN784_HUMAN']
