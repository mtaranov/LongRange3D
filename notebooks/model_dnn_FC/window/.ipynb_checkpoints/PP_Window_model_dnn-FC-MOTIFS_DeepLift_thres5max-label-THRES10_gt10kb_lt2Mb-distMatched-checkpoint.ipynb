# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import sys
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import copy
sys.path.append('/users/mtaranov/LongRange3D/')
from models_motif_exp import LongRangeDNN_FC
from utils import normalize_features_sampl_by_f, concat_motifs,get_features, get_labels, subsample_data, normalize_features, reconstruct_2d, printMatrix, binarize, zscore, get_2D, plot_prediction, change_scale 
#from sklearn.preprocessing import MinMaxScaler, StandardScaler
#from dragonn.models import Model, SequenceDNN
#from keras.models import Sequential
#from keras.callbacks import Callback, EarlyStopping
#from keras.layers.core import (
#    Activation, Dense, Dropout, Flatten,
#    Permute, Reshape, TimeDistributedDense
#)
#from keras.layers.convolutional import Convolution2D, MaxPooling2D
#from keras.layers.recurrent import GRU
#from keras.regularizers import l1

#from deeplift import keras_conversion as kc
#from deeplift.blobs import MxtsMode
# Out:
# Using Theano backend.
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# Using gpu device 7: GeForce GTX TITAN X (CNMeM is enabled with initial size: 2500 MB, cuDNN 5105)

# %%
contacts='PP_PE'
path='/users/mtaranov/datasets_3d/dist_matched_'+contacts+'/'

X_train = np.load(path+'motifs/train_'+contacts+'_out_btw_nodes_3_0.0001/mat.npy')
X_test = np.load(path+'motifs/test_'+contacts+'_out_btw_nodes_3_0.0001/mat.npy')
X_valid = np.load(path+'motifs/valid_'+contacts+'_out_btw_nodes_3_0.0001/mat.npy')

y_train = get_labels(path+'y_train_thres_10.npy')
y_test = get_labels(path+'y_test_thres_10.npy')
y_valid = get_labels(path+'y_valid_thres_10.npy')

# %%
X_train.shape, X_test.shape, X_valid.shape
# Out:
# ((4824, 1920), (1812, 1920), (2872, 1920))

# %%
X_train_normalized, X_valid_normalized, X_test_normalized = normalize_features_sampl_by_f(X_train, X_valid, X_test)

#X_train_normalized_subsampled, y_train_subsampled = subsample_data(X_train_normalized, y_train)
#X_valid_normalized_subsampled, y_valid_subsampled = subsample_data(X_valid_normalized, y_valid)
#X_test_normalized_subsampled, y_test_subsampled = subsample_data(X_test_normalized, y_test)

#X_train_scaled_subsampled, y_train_subsampled = subsample_data(X_train_scaled, y_train)
#X_valid_scaled_subsampled, y_valid_subsampled = subsample_data(X_valid_scaled, y_valid)
#X_test_scaled_subsampled, y_test_subsampled = subsample_data(X_test_scaled, y_test)

# %%
from models_motif_exp import LongRangeDNN_FC
dnn_normalized = LongRangeDNN_FC(num_features=1920, use_deep_CNN=False)
validation_data = (X_valid_normalized, y_valid)
dnn_normalized.train(X_train_normalized, y_train, validation_data)
# Out:
# Training model...
# Train on 4824 samples, validate on 2872 samples
# Epoch 1/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 1.2155Epoch 0: validation loss: 0.887
# Balanced Accuracy: 53.80%	 auROC: 0.653	 auPRC: 0.658	 auPRG: 0.287
# Recall at 5%|10%|20% FDR: 0.8%|3.4%|12.7%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 9s - loss: 1.2153 - val_loss: 0.8875
# Epoch 2/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 0.3777Epoch 1: validation loss: 0.763
# Balanced Accuracy: 62.88%	 auROC: 0.705	 auPRC: 0.660	 auPRG: 0.425
# Recall at 5%|10%|20% FDR: 0.0%|0.0%|0.5%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 0.3780 - val_loss: 0.7632
# Epoch 3/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 0.1725Epoch 2: validation loss: 0.586
# Balanced Accuracy: 74.27%	 auROC: 0.816	 auPRC: 0.772	 auPRG: 0.667
# Recall at 5%|10%|20% FDR: 0.0%|0.0%|62.0%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 0
	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 0.0015 - val_loss: 0.4475
# Epoch 30/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 0.0013Epoch 29: validation loss: 0.454
# Balanced Accuracy: 83.70%	 auROC: 0.920	 auPRC: 0.935	 auPRG: 0.887
# Recall at 5%|10%|20% FDR: 70.4%|76.9%|87.0%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 0.0013 - val_loss: 0.4539
# Epoch 31/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 0.0012Epoch 30: validation loss: 0.454
# Balanced Accuracy: 83.91%	 auROC: 0.921	 auPRC: 0.935	 auPRG: 0.887
# Recall at 5%|10%|20% FDR: 70.8%|77.2%|86.9%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 0.0012 - val_loss: 0.4535
# Epoch 32/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 0.0011Epoch 31: validation loss: 0.458
# Balanced Accuracy: 83.70%	 auROC: 0.921	 auPRC: 0.935	 auPRG: 0.887
# Recall at 5%|10%|20% FDR: 70.6%|77.2%|87.1%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 0.0012 - val_loss: 0.4584
# Epoch 33/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 0.0010Epoch 32: validation loss: 0.459
# Balanced Accuracy: 84.09%	 auROC: 0.920	 auPRC: 0.935	 auPRG: 0.887
# Recall at 5%|10%|20% FDR: 70.4%|76.8%|87.0%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 0.0010 - val_loss: 0.4592
# Epoch 34/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 9.6073e-04Epoch 33: validation loss: 0.460
# Balanced Accuracy: 84.16%	 auROC: 0.921	 auPRC: 0.936	 auPRG: 0.888
# Recall at 5%|10%|20% FDR: 71.0%|77.0%|87.3%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 9.9654e-04 - val_loss: 0.4601
# Epoch 35/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 9.2021e-04Epoch 34: validation loss: 0.466
# Balanced Accuracy: 83.57%	 auROC: 0.921	 auPRC: 0.935	 auPRG: 0.888
# Recall at 5%|10%|20% FDR: 70.5%|77.5%|87.0%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 9.2542e-04 - val_loss: 0.4662
# Epoch 36/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 9.4793e-04Epoch 35: validation loss: 0.466
# Balanced Accuracy: 83.67%	 auROC: 0.921	 auPRC: 0.936	 auPRG: 0.888
# Recall at 5%|10%|20% FDR: 70.5%|77.6%|87.3%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 9.6887e-04 - val_loss: 0.4665
# Epoch 37/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 7.6964e-04Epoch 36: validation loss: 0.469
# Balanced Accuracy: 84.02%	 auROC: 0.921	 auPRC: 0.935	 auPRG: 0.887
# Recall at 5%|10%|20% FDR: 70.5%|77.1%|87.2%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 7.8001e-04 - val_loss: 0.4691
# Epoch 38/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 7.8245e-04Epoch 37: validation loss: 0.468
# Balanced Accuracy: 84.05%	 auROC: 0.921	 auPRC: 0.936	 auPRG: 0.888
# Recall at 5%|10%|20% FDR: 71.1%|77.5%|87.5%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 8.0232e-04 - val_loss: 0.4683
# Epoch 39/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 7.9894e-04Epoch 38: validation loss: 0.469
# Balanced Accuracy: 84.09%	 auROC: 0.921	 auPRC: 0.936	 auPRG: 0.889
# Recall at 5%|10%|20% FDR: 71.1%|77.0%|87.5%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 9.3874e-04 - val_loss: 0.4685
# Epoch 40/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 7.9382e-04Epoch 39: validation loss: 0.474
# Balanced Accuracy: 84.16%	 auROC: 0.920	 auPRC: 0.936	 auPRG: 0.888
# Recall at 5%|10%|20% FDR: 70.5%|77.5%|87.2%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 7.9709e-04 - val_loss: 0.4742
# Epoch 41/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 7.0347e-04Epoch 40: validation loss: 0.476
# Balanced Accuracy: 83.98%	 auROC: 0.920	 auPRC: 0.936	 auPRG: 0.888
# Recall at 5%|10%|20% FDR: 70.4%|77.5%|87.3%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 7.1494e-04 - val_loss: 0.4758
# Epoch 42/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 7.0330e-04Epoch 41: validation loss: 0.474
# Balanced Accuracy: 83.88%	 auROC: 0.921	 auPRC: 0.936	 auPRG: 0.888
# Recall at 5%|10%|20% FDR: 70.1%|77.4%|87.5%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 7.8747e-04 - val_loss: 0.4741
# Epoch 43/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 7.0616e-04Epoch 42: validation loss: 0.472
# Balanced Accuracy: 83.88%	 auROC: 0.922	 auPRC: 0.937	 auPRG: 0.890
# Recall at 5%|10%|20% FDR: 70.8%|77.5%|87.5%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 7.4463e-04 - val_loss: 0.4724
# Epoch 44/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 5.4984e-04Epoch 43: validation loss: 0.477
# Balanced Accuracy: 83.81%	 auROC: 0.921	 auPRC: 0.936	 auPRG: 0.889
# Recall at 5%|10%|20% FDR: 70.3%|77.2%|88.0%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 8.8995e-04 - val_loss: 0.4772
# Epoch 45/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 8.7055e-04Epoch 44: validation loss: 0.486
# Balanced Accuracy: 84.30%	 auROC: 0.920	 auPRC: 0.936	 auPRG: 0.887
# Recall at 5%|10%|20% FDR: 70.2%|76.4%|87.1%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 8.7653e-04 - val_loss: 0.4861
# Epoch 46/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 6.0602e-04Epoch 45: validation loss: 0.481
# Balanced Accuracy: 84.47%	 auROC: 0.922	 auPRC: 0.937	 auPRG: 0.890
# Recall at 5%|10%|20% FDR: 71.2%|77.4%|87.5%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 6.4301e-04 - val_loss: 0.4810
# Epoch 47/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 5.5743e-04Epoch 46: validation loss: 0.482
# Balanced Accuracy: 83.84%	 auROC: 0.922	 auPRC: 0.937	 auPRG: 0.890
# Recall at 5%|10%|20% FDR: 70.7%|77.2%|88.0%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 6.1094e-04 - val_loss: 0.4824
# Epoch 48/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 5.3010e-04Epoch 47: validation loss: 0.485
# Balanced Accuracy: 83.84%	 auROC: 0.922	 auPRC: 0.937	 auPRG: 0.890
# Recall at 5%|10%|20% FDR: 70.5%|77.1%|87.8%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 5.2839e-04 - val_loss: 0.4845
# Epoch 49/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 4.8539e-04Epoch 48: validation loss: 0.485
# Balanced Accuracy: 83.74%	 auROC: 0.922	 auPRC: 0.937	 auPRG: 0.890
# Recall at 5%|10%|20% FDR: 70.6%|77.1%|87.8%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 5.0793e-04 - val_loss: 0.4852
# Epoch 50/100
# 4750/4824 [============================>.] - ETA: 0s - loss: 5.0550e-04Epoch 49: validation loss: 0.486
# Balanced Accuracy: 83.98%	 auROC: 0.922	 auPRC: 0.937	 auPRG: 0.890
# Recall at 5%|10%|20% FDR: 70.3%|77.2%|87.5%	 Num Positives: 1436	 Num Negatives: 1436
#
# 4824/4824 [==============================] - 8s - loss: 5.0715e-04 - val_loss: 0.4865

# %%
print(dnn_normalized.test(X_test_normalized, y_test))
print(dnn_normalized.test(X_train_normalized, y_train))
print(dnn_normalized.test(X_valid_normalized, y_valid))
# Out:
# Balanced Accuracy: 84.33%	 auROC: 0.919	 auPRC: 0.933	 auPRG: 0.880
# Recall at 5%|10%|20% FDR: 65.3%|78.9%|88.5%	 Num Positives: 906	 Num Negatives: 906
# Balanced Accuracy: 100.00%	 auROC: 1.000	 auPRC: 1.000	 auPRG: 1.000
# Recall at 5%|10%|20% FDR: 100.0%|100.0%|100.0%	 Num Positives: 2412	 Num Negatives: 2412
# Balanced Accuracy: 83.98%	 auROC: 0.922	 auPRC: 0.937	 auPRG: 0.890
# Recall at 5%|10%|20% FDR: 70.3%|77.2%|87.5%	 Num Positives: 1436	 Num Negatives: 1436
