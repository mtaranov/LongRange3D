# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import sys
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import copy
sys.path.append('/users/mtaranov/LongRange3D/')
from models_binnedFeat import LongRangeDNN
from utils import get_features, get_labels, subsample_data, normalize_features, reconstruct_2d, printMatrix, binarize, zscore, get_2D, plot_prediction, change_scale 
#from sklearn.preprocessing import MinMaxScaler, StandardScaler
#from dragonn.models import Model, SequenceDNN
#from keras.models import Sequential
#from keras.callbacks import Callback, EarlyStopping
#from keras.layers.core import (
#    Activation, Dense, Dropout, Flatten,
#    Permute, Reshape, TimeDistributedDense
#)
#from keras.layers.convolutional import Convolution2D, MaxPooling2D
#from keras.layers.recurrent import GRU
#from keras.regularizers import l1

#from deeplift import keras_conversion as kc
#from deeplift.blobs import MxtsMode
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
contacts='PP'
path='/users/mtaranov/datasets_3d/dist_matched_'+contacts+'/'
X_train = get_features(path+'X_train_thres_10.npy')
y_train = get_labels(path+'y_train_thres_10.npy')
X_valid = get_features(path+'X_valid_thres_10.npy')
y_valid = get_labels(path+'y_valid_thres_10.npy')
X_test = get_features(path+'X_test_thres_10.npy')
y_test = get_labels(path+'y_test_thres_10.npy')

# %%
X_train_normalized, X_valid_normalized, X_test_normalized = normalize_features(X_train, X_valid, X_test)

#X_train_normalized_subsampled, y_train_subsampled = subsample_data(X_train_normalized, y_train)
#X_valid_normalized_subsampled, y_valid_subsampled = subsample_data(X_valid_normalized, y_valid)
#X_test_normalized_subsampled, y_test_subsampled = subsample_data(X_test_normalized, y_test)

#X_train_scaled_subsampled, y_train_subsampled = subsample_data(X_train_scaled, y_train)
#X_valid_scaled_subsampled, y_valid_subsampled = subsample_data(X_valid_scaled, y_valid)
#X_test_scaled_subsampled, y_test_subsampled = subsample_data(X_test_scaled, y_test)

# %% [markdown]
# # without distance

# %%
scores_from_10_iter =[]
for i in range(10):
    dnn_normalized = LongRangeDNN(num_features=10, use_deep_CNN=True)
    validation_data = (X_valid_normalized[:, :, :10, :], y_valid)
    dnn_normalized.train(X_train_normalized[:, :, :10, :], y_train, validation_data)
    dnn_normalized.save(contacts+'dnn_CONV_wo_dist', '/users/mtaranov/LongRange3D/')
    print "Iter",i, " summary:"
    print(dnn_normalized.test(X_test_normalized[:, :, :10, :], y_test))
    print(dnn_normalized.test(X_train_normalized[:, :, :10, :], y_train))
    print(dnn_normalized.test(X_valid_normalized[:, :, :10, :], y_valid))
    
    weights='/users/mtaranov/LongRange3D/weights/'+contacts+'dnn_CONV_wo_dist.weights.h5'
    json_model='/users/mtaranov/LongRange3D/models/'+contacts+'dnn_CONV_wo_dist.arch.json'
    scores = dnn_normalized.deeplift(X_valid_normalized[:, :, :10, :], weights, json_model, batch_size=128)
    scores_from_10_iter.append(scores)

# pred_probs_test = dnn_normalized.predict(X_test_normalized[:, :, :10, :])
# #np.save("model_predictions/test_set_upperTriangle_noDiag_reads_with_distances_full_valid.npy", pred_probs_test)
# pred_probs_valid = dnn_normalized.predict(X_valid_normalized[:, :, :10, :])
# #np.save("model_predictions/valid_set_upperTriangle_noDiag_reads_with_distances_full_valid.npy", pred_probs_valid)
# pred_probs_train = dnn_normalized.predict(X_train_normalized[:, :, :10, :])
# #np.save("model_predictions/train_set_upperTriangle_noDiag_reads_with_distances_full_valid.npy", pred_probs_train)
# Out:
# Training model...
# Train on 1152 samples, validate on 728 samples
# Epoch 1/100
# 1000/1152 [=========================>....] - ETA: 1s - loss: 1.5363Epoch 0: validation loss: 0.676
# Balanced Accuracy: 57.55%	 auROC: 0.610	 auPRC: 0.599	 auPRG: 0.199
# Recall at 5%|10%|20% FDR: 0.0%|0.0%|0.0%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 11s - loss: 1.5288 - val_loss: 0.6765
# Epoch 2/100
# 1000/1152 [=========================>....] - ETA: 1s - loss: 0.7269Epoch 1: validation loss: 0.653
# Balanced Accuracy: 62.36%	 auROC: 0.681	 auPRC: 0.663	 auPRG: 0.370
# Recall at 5%|10%|20% FDR: 0.3%|0.3%|0.3%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 11s - loss: 0.7296 - val_loss: 0.6533
# Epoch 3/100
# 1000/1152 [=========================>....] - ETA: 1s - loss: 0.5187Epoch 2: validation loss: 0.625
# Balanced Accuracy: 68.96%	 auROC: 0.729	 auPRC: 0.718	 auPRG: 0.490
# Recall at 5%|10%|20% FDR: 0.5%|0.5%|30.2%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 12s - loss: 0.5114 - val_loss: 0.6253
# Epoch 4/100
# 1000/1152 [=========================>....] - ETA: 1s - loss: 0.3854Epoch 3: validation loss: 0.604
# Balanced Accuracy: 69.78%	 auROC: 0.744	 auPRC: 0.747	 auPRG: 0.512
# Recall at 5%|10%|20% FDR: 0.8%|0.8%|50.5%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 11s - loss: 0.3874 - val_loss: 0.6041
# Epoch 5/100
# 1000/1152 [=========================>....] - ETA: 1s - loss: 0.2789Epoch 4: validation loss: 0.586
# Balanced Accuracy: 70.33%	 auROC: 0.757	 auPRC: 0.761	 auPRG: 0.528
# Recall at 5%|10%|20% FDR: 0.5%|2.7%|52.5%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 11s - loss: 0.2880 - val_loss: 0.5863
# Epoch 6/100
# 1000/1152 [=========================>....] - ETA: 1s - loss: 0.2406Epoch 5: validation loss: 0.574
# Balanced Accuracy: 70.74%	 auROC: 0.771	 auPRC: 0.772	 auPRG: 0.557
# Recall at 5%|10%|20% FDR: 0.3%|0.3%|53.0%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 11s - loss: 0.2443 - val_loss: 0.5737
# Epoch 7/100
# 1000/1152 [=========================>....] - ETA: 1s - loss: 0.1983Epoch 6: validation loss: 0.569
# Balanced Accuracy: 70.60%	 auROC: 0.781	 auPRC: 0.787	 auPRG: 0.581
# Recall at 5%|10%|20% FDR: 1.1%|33.2%|55.5%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 12s - loss: 0.2028 - val_loss: 0.5693
# Epoch 8/100
# 1000/1152 [=========================>....] - ETA: 1s - loss: 0.1799Epoch 7: validation loss: 0.577
# Balanced Accuracy: 70.33%	 auROC: 0.784	 auPRC: 0.789	 auPRG: 0.589
# Recall at 5%|10%|20% FDR: 1.1%|30.2%|57.7%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 11s - loss: 0.1770 - val_loss: 0.5769
# Epoch 9/100
# 1000/1152 [=========================>....] - ETA: 1s - loss: 0.1441Epoch 8: validation loss: 0.591
# Balanced Accuracy: 71.02%	 auROC: 0.786	 auPRC: 0.789	 auPRG: 0.594
# Recall at 5%|10%|20% FDR: 1.9%|29.7%|54.7%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 11s - loss: 0.1447 - val_loss: 0.5914
# Epoch 10/100
# 1000/1152 [=========================>....] - ETA: 1s - loss: 0.1301Epoch 9: validation loss: 0.607
# Balanced Accuracy: 71.29%	 auROC: 0.787	 auPRC: 0.791	 auPRG: 0.591
# Recall at 5%|10%|20% FDR: 1.9%|37.4%|55.8%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 11s - loss: 0.1344 - val_loss: 0.6065
# Epoch 11/100
# 1000/1152 [=========================>....] - ETA: 0s - loss: 0.1123Epoch 10: validation loss: 0.620
# Balanced Accuracy: 71.29%	 auROC: 0.789	 auPRC: 0.793	 auPRG: 0.593
# Recall at 5%|10%|20% FDR: 1.4%|41.5%|52.5%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 7s - loss: 0.1094 - val_loss: 0.6200
# Epoch 12/100
# 1000/1152 [=========================>....] - ETA: 0s - loss: 0.0963Epoch 11: validation loss: 0.631
# Balanced Accuracy: 71.70%	 auROC: 0.791	 auPRC: 0.800	 auPRG: 0.600
# Recall at 5%|10%|20% FDR: 6.6%|20.1%|58.2%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 7s - loss: 0.0983 - val_loss: 0.6309
# Epoch 13/100
# 1000/1152 [=========================>....] - ETA: 0s - loss: 0.0848Epoch 12: validation loss: 0.644
# Balanced Accuracy: 71.70%	 auROC: 0.792	 auPRC: 0.803	 auPRG: 0.601
# Recall at 5%|10%|20% FDR: 13.2%|21.2%|58.0%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 7s - loss: 0.0866 - val_loss: 0.6445
# Epoch 14/100
# 1000/1152 [=========================>....] - ETA: 0s - loss: 0.0758Epoch 13: validation loss: 0.662
# Balanced Accuracy: 70.74%	 auROC: 0.789	 auPRC: 0.804	 auPRG: 0.589
# Recall at 5%|10%|20% FDR: 19.8%|39.6%|55.8%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 7s - loss: 0.0802 - val_loss: 0.6617
# Epoch 15/100
# 1000/1152 [=========================>....] - ETA: 0s - loss: 0.0793Epoch 14: validation loss: 0.674
# Balanced Accuracy: 70.19%	 auROC: 0.787	 auPRC: 0.802	 auPRG: 0.585
# Recall at 5%|10%|20% FDR: 18.7%|39.0%|54.4%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 7s - loss: 0.0883 - val_loss: 0.6736
# Epoch 16/100
# 1000/1152 [=========================>....] - ETA: 0s - loss: 0.0731Epoch 15: validation loss: 0.684
# Balanced Accuracy: 71.57%	 auROC: 0.787	 auPRC: 0.799	 auPRG: 0.587
# Recall at 5%|10%|20% FDR: 18.1%|35.7%|54.1%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 7s - loss: 0.0760 - val_loss: 0.6839
# Epoch 17/100
# 1000/1152 [=========================>....] - ETA: 0s - loss: 0.0663Epoch 16: validation loss: 0.701
# Balanced Accuracy: 71.29%	 auROC: 0.784	 auPRC: 0.795	 auPRG: 0.585
# Recall at 5%|10%|20% FDR: 17.6%|20.3%|51.4%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 7s - loss: 0.0685 - val_loss: 0.7011
# Epoch 18/100
# 1000/1152 [=========================>....] - ETA: 0s - loss: 0.0581Epoch 17: validation loss: 0.707
# Balanced Accuracy: 71.15%	 auROC: 0.783	 auPRC: 0.795	 auPRG: 0.580
# Recall at 5%|10%|20% FDR: 17.0%|19.2%|52.7%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 7s - loss: 0.0658 - val_loss: 0.7073
# Epoch 19/100
# 1000/1152 [=========================>....] - ETA: 1s - loss: 0.0588Epoch 18: validation loss: 0.717
# Balanced Accuracy: 71.29%	 auROC: 0.780	 auPRC: 0.790	 auPRG: 0.577
# Recall at 5%|10%|20% FDR: 13.7%|18.4%|54.4%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 10s - loss: 0.0625 - val_loss: 0.7166
# Epoch 20/100
# 1000/1152 [=========================>....] - ETA: 1s - loss: 0.0629Epoch 19: validation loss: 0.730
# Balanced Accuracy: 71.29%	 auROC: 0.778	 auPRC: 0.786	 auPRG: 0.571
# Recall at 5%|10%|20% FDR: 0.8%|20.9%|54.7%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 11s - loss: 0.0623 - val_loss: 0.7298
# Epoch 21/100
# 1000/1152 [=========================>....] - ETA: 1s - loss: 0.0601Epoch 20: validation loss: 0.737
# Balanced Accuracy: 71.15%	 auROC: 0.777	 auPRC: 0.788	 auPRG: 0.562
# Recall at 5%|10%|20% FDR: 5.5%|37.9%|52.2%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 8s - loss: 0.0639 - val_loss: 0.7371
# Epoch 22/100
# 1000/1152 [=========================>....] - ETA: 1s - loss: 0.0485Epoch 21: validation loss: 0.743
# Balanced Accuracy: 71.02%	 auROC: 0.777	 auPRC: 0.786	 auPRG: 0.564
# Recall at 5%|10%|20% FDR: 5.5%|36.0%|50.5%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 7s - loss: 0.0582 - val_loss: 0.7431
# Epoch 23/100
# 1000/1152 [=========================>....] - ETA: 1s - loss: 0.0568Epoch 22: validation loss: 0.755
# Balanced Accuracy: 71.15%	 auROC: 0.775	 auPRC: 0.781	 auPRG: 0.561
# Recall at 5%|10%|20% FDR: 0.8%|34.3%|51.6%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 8s - loss: 0.0586 - val_loss: 0.7554
# Epoch 24/100
# 1000/1152 [=========================>....] - ETA: 1s - loss: 0.0516Epoch 23: validation loss: 0.749
# Balanced Accuracy: 70.88%	 auROC: 0.778	 auPRC: 0.791	 auPRG: 0.566
# Recall at 5%|10%|20% FDR: 9.3%|35.7%|53.0%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 8s - loss: 0.0528 - val_loss: 0.7486
# Epoch 25/100
# 1000/1152 [=========================>....] - ETA: 0s - loss: 0.0598Epoch 24: validation loss: 0.749
# Balanced Accuracy: 70.88%	 auROC: 0.779	 auPRC: 0.792	 auPRG: 0.572
# Recall at 5%|10%|20% FDR: 8.2%|35.4%|54.4%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 8s - loss: 0.0623 - val_loss: 0.7491
# Epoch 26/100
# 1000/1152 [=========================>....] - ETA: 0s - loss: 0.0489Epoch 25: validation loss: 0.761
# Balanced Accuracy: 71.29%	 auROC: 0.778	 auPRC: 0.791	 auPRG: 0.571
# Recall at 5%|10%|20% FDR: 6.3%|32.7%|52.7%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 3s - loss: 0.0492 - val_loss: 0.7615
# Epoch 27/100
# 1000/1152 [=========================>....] - ETA: 0s - loss: 0.0489Epoch 26: validation loss: 0.765
# Balanced Accuracy: 71.29%	 auROC: 0.780	 auPRC: 0.796	 auPRG: 0.569
# Recall at 5%|10%|20% FDR: 8.8%|33.8%|53.6%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 3s - loss: 0.0499 - val_loss: 0.7648
# Epoch 28/100
# 1000/1152 [=========================>....] - ETA: 0s - loss: 0.0408Epoch 27: validation loss: 0.773
# Balanced Accuracy: 71.02%	 auROC: 0.780	 auPRC: 0.798	 auPRG: 0.567
# Recall at 5%|10%|20% FDR: 14.6%|36.0%|53.8%	 Num Positives: 364	 Num Negatives: 364
#
# 1152/1152 [==============================] - 3s - loss: 0.0442 - val_loss: 0.7733
# Iter 0  summary:
# Balanced Accuracy: 72.05%	 auROC: 0.780	 auPRC: 0.778	 auPRG: 0.602
# Recall at 5%|10%|20% FDR: 2.6%|2.6%|60.7%	 Num Positives: 229	 Num Negatives: 229
# Balanced Accuracy: 99.65%	 auROC: 1.000	 auPRC: 1.000	 auPRG: 1.000
# Recall at 5%|10%|20% FDR: 100.0%|100.0%|100.0%	 Num Positives: 576	 Num Negatives: 576
# Balanced Accuracy: 71.02%	 auROC: 0.780	 auPRC: 0.798	 auPRG: 0.567
# Recall at 5%|10%|20% FDR: 14.6%|36.0%|53.8%	 Num Positives: 364	 Num Negatives: 364
# nonlinear_mxts_mode is set to: Gradient
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-34-e06b33fbb96f> in <module>()
#      12     weights='/users/mtaranov/LongRange3D/weights/'+contacts+'dnn_CONV_wo_dist.weights.h5'
#      13     json_model='/users/mtaranov/LongRange3D/models/'+contacts+'dnn_CONV_wo_dist.arch.json'
# ---> 14     scores = dnn_normalized.deeplift(X_valid_normalized[:, :, :10, :], weights, json_model, batch_size=128)
#      15     scores_from_10_iter.append(scores)
#      16
#
# /users/mtaranov/LongRange3D/models.pyc in deeplift(self, X, keras_model_weights, keras_model_json, batch_size)
#     171         # run deeplift
#     172         deeplift_model = kc.convert_sequential_model(
# --> 173            self.model, nonlinear_mxts_mode=NonlinearMxtsMode.Gradient)
#     174
#     175         # compile scoring function
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/conversion/keras_conversion.pyc in convert_sequential_model(model, num_dims, nonlinear_mxts_mode, verbose, dense_mxts_mode, conv_mxts_mode, maxpool_deeplift_mode, layer_overrides)
#     369                 layer_overrides=layer_overrides)
#     370     deeplift.util.connect_list_of_layers(converted_layers)
# --> 371     converted_layers[-1].build_fwd_pass_vars()
#     372     return models.SequentialModel(converted_layers)
#     373
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/activations.pyc in _build_fwd_pass_vars(self)
#      31     def _build_fwd_pass_vars(self):
#      32         #can't just inherit from parent due to gradient building
# ---> 33         self._build_fwd_pass_vars_core()
#      34         self._activation_vars = self._build_activation_vars(
#      35                                  self._get_input_activation_vars())
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     336             mxts will not be correct
#     337         """
# --> 338         self._build_fwd_pass_vars_core()
#     339         self._activation_vars =\
#     340             self._build_activation_vars(
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     336             mxts will not be correct
#     337         """
# --> 338         self._build_fwd_pass_vars_core()
#     339         self._activation_vars =\
#     340             self._build_activation_vars(
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     336             mxts will not be correct
#     337         """
# --> 338         self._build_fwd_pass_vars_core()
#     339         self._activation_vars =\
#     340             self._build_activation_vars(
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/activations.pyc in _build_fwd_pass_vars(self)
#      31     def _build_fwd_pass_vars(self):
#      32         #can't just inherit from parent due to gradient building
# ---> 33         self._build_fwd_pass_vars_core()
#      34         self._activation_vars = self._build_activation_vars(
#      35                                  self._get_input_activation_vars())
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     336             mxts will not be correct
#     337         """
# --> 338         self._build_fwd_pass_vars_core()
#     339         self._activation_vars =\
#     340             self._build_activation_vars(
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     336             mxts will not be correct
#     337         """
# --> 338         self._build_fwd_pass_vars_core()
#     339         self._activation_vars =\
#     340             self._build_activation_vars(
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     336             mxts will not be correct
#     337         """
# --> 338         self._build_fwd_pass_vars_core()
#     339         self._activation_vars =\
#     340             self._build_activation_vars(
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/activations.pyc in _build_fwd_pass_vars(self)
#      31     def _build_fwd_pass_vars(self):
#      32         #can't just inherit from parent due to gradient building
# ---> 33         self._build_fwd_pass_vars_core()
#      34         self._activation_vars = self._build_activation_vars(
#      35                                  self._get_input_activation_vars())
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     336             mxts will not be correct
#     337         """
# --> 338         self._build_fwd_pass_vars_core()
#     339         self._activation_vars =\
#     340             self._build_activation_vars(
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     336             mxts will not be correct
#     337         """
# --> 338         self._build_fwd_pass_vars_core()
#     339         self._activation_vars =\
#     340             self._build_activation_vars(
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     336             mxts will not be correct
#     337         """
# --> 338         self._build_fwd_pass_vars_core()
#     339         self._activation_vars =\
#     340             self._build_activation_vars(
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/activations.pyc in _build_fwd_pass_vars(self)
#      31     def _build_fwd_pass_vars(self):
#      32         #can't just inherit from parent due to gradient building
# ---> 33         self._build_fwd_pass_vars_core()
#      34         self._activation_vars = self._build_activation_vars(
#      35                                  self._get_input_activation_vars())
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     336             mxts will not be correct
#     337         """
# --> 338         self._build_fwd_pass_vars_core()
#     339         self._activation_vars =\
#     340             self._build_activation_vars(
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     336             mxts will not be correct
#     337         """
# --> 338         self._build_fwd_pass_vars_core()
#     339         self._activation_vars =\
#     340             self._build_activation_vars(
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     336             mxts will not be correct
#     337         """
# --> 338         self._build_fwd_pass_vars_core()
#     339         self._activation_vars =\
#     340             self._build_activation_vars(
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/activations.pyc in _build_fwd_pass_vars(self)
#      31     def _build_fwd_pass_vars(self):
#      32         #can't just inherit from parent due to gradient building
# ---> 33         self._build_fwd_pass_vars_core()
#      34         self._activation_vars = self._build_activation_vars(
#      35                                  self._get_input_activation_vars())
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     336             mxts will not be correct
#     337         """
# --> 338         self._build_fwd_pass_vars_core()
#     339         self._activation_vars =\
#     340             self._build_activation_vars(
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     336             mxts will not be correct
#     337         """
# --> 338         self._build_fwd_pass_vars_core()
#     339         self._activation_vars =\
#     340             self._build_activation_vars(
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     336             mxts will not be correct
#     337         """
# --> 338         self._build_fwd_pass_vars_core()
#     339         self._activation_vars =\
#     340             self._build_activation_vars(
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/activations.pyc in _build_fwd_pass_vars(self)
#      31     def _build_fwd_pass_vars(self):
#      32         #can't just inherit from parent due to gradient building
# ---> 33         self._build_fwd_pass_vars_core()
#      34         self._activation_vars = self._build_activation_vars(
#      35                                  self._get_input_activation_vars())
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     336             mxts will not be correct
#     337         """
# --> 338         self._build_fwd_pass_vars_core()
#     339         self._activation_vars =\
#     340             self._build_activation_vars(
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     336             mxts will not be correct
#     337         """
# --> 338         self._build_fwd_pass_vars_core()
#     339         self._activation_vars =\
#     340             self._build_activation_vars(
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/activations.pyc in _build_fwd_pass_vars(self)
#      31     def _build_fwd_pass_vars(self):
#      32         #can't just inherit from parent due to gradient building
# ---> 33         self._build_fwd_pass_vars_core()
#      34         self._activation_vars = self._build_activation_vars(
#      35                                  self._get_input_activation_vars())
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     336             mxts will not be correct
#     337         """
# --> 338         self._build_fwd_pass_vars_core()
#     339         self._activation_vars =\
#     340             self._build_activation_vars(
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     336             mxts will not be correct
#     337         """
# --> 338         self._build_fwd_pass_vars_core()
#     339         self._activation_vars =\
#     340             self._build_activation_vars(
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/activations.pyc in _build_fwd_pass_vars(self)
#      31     def _build_fwd_pass_vars(self):
#      32         #can't just inherit from parent due to gradient building
# ---> 33         self._build_fwd_pass_vars_core()
#      34         self._activation_vars = self._build_activation_vars(
#      35                                  self._get_input_activation_vars())
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_core(self)
#     327
#     328     def _build_fwd_pass_vars_core(self):
# --> 329         self._build_fwd_pass_vars_for_all_inputs()
#     330         self._shape = self._compute_shape(self._get_input_shape())
#     331
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars_for_all_inputs(self)
#     417
#     418     def _build_fwd_pass_vars_for_all_inputs(self):
# --> 419         self.inputs.build_fwd_pass_vars(output_layer=self)
#     420
#     421     def _reset_built_fwd_pass_vars_for_inputs(self):
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in build_fwd_pass_vars(self, output_layer)
#     166             self._output_layers.append(output_layer)
#     167         if (self._built_fwd_pass_vars == False):
# --> 168             self._build_fwd_pass_vars()
#     169             self._built_fwd_pass_vars = True
#     170
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/core.pyc in _build_fwd_pass_vars(self)
#     345          self._build_diff_from_reference_vars()
#     346         self._pos_contribs, self._neg_contribs =\
# --> 347             self._build_pos_and_neg_contribs()
#     348         self._pos_mxts = B.zeros_like(self.get_activation_vars())
#     349         self._neg_mxts = B.zeros_like(self.get_activation_vars())
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/convolution.pyc in _build_pos_and_neg_contribs(self)
#     316             neg_contribs = (self._compute_conv_without_bias(
#     317                              x=inp_diff_ref*(inp_diff_ref<0.0),
# --> 318                              W=self.W*(self.W > 0.0))
#     319                            +self._compute_conv_without_bias(
#     320                              x=inp_diff_ref*(inp_diff_ref>0.0),
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/blobs/convolution.pyc in _compute_conv_without_bias(self, x, W)
#     347                                   filters=W,
#     348                                   border_mode=self.border_mode,
# --> 349                                   subsample=self.strides)
#     350         return conv_without_bias
#     351
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/deeplift/backend/theano_backend.pyc in conv2d(inp, filters, border_mode, subsample)
#     151             "haven't handled even filter shapes for border mode 'half'"
#     152     return T.nnet.conv2d(input=inp,
# --> 153                          filters=T.cast(theano.shared(value=filters),
#     154                                         dtype=theano.config.floatX),
#     155                          border_mode=border_mode,
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/compile/sharedvalue.pyc in shared(value, name, strict, allow_downcast, **kwargs)
#     266             try:
#     267                 var = ctor(value, name=name, strict=strict,
# --> 268                            allow_downcast=allow_downcast, **kwargs)
#     269                 utils.add_tag_trace(var)
#     270                 return var
#
# /users/mtaranov/local/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/var.pyc in float32_shared_constructor(value, name, strict, allow_downcast, borrow, broadcastable, target)
#     186         # type.broadcastable is guaranteed to be a tuple, which this next
#     187         # function requires
# --> 188         deviceval = type_support_filter(value, type.broadcastable, False, None)
#     189
#     190     try:
#
# MemoryError: ('Error allocating 36000000 bytes of device memory (CNMEM_STATUS_OUT_OF_MEMORY).', "you might consider using 'theano.shared(..., borrow=True)'")

# %%
features = ['ATAC', 'CTCF', 'POL3', 'TP63', 'LSD1', 'H3K27ac', 'H3K27me3', 'H3K4me1', 'H3K4me3', 'H3K9ac']
for i in range(10):
    # mean feature importance on node 1
    plt.plot(np.mean(scores_from_10_iter[i][:, 0, :, 0], axis=0))
    x = [float(i) for i in range(np.shape(scores_from_10_iter[i])[2])]
    plt.xticks(x, features, rotation='vertical')
    plt.title('Node1 - interaction hubs')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-9817f4f96498> in <module>()
#       2 for i in range(10):
#       3     # mean feature importance on node 1
# ----> 4     plt.plot(np.mean(scores_from_10_iter[i][:, 0, :, 0], axis=0))
#       5     x = [float(i) for i in range(np.shape(scores_from_10_iter[i])[2])]
#       6     plt.xticks(x, features, rotation='vertical')
#
# IndexError: list index out of range

# %%
for i in range(10):
    # mean feature importance on node 1
    plt.plot(np.mean(scores_from_10_iter[i][:, 0, :, 1], axis=0))
    x = [float(i) for i in range(np.shape(scores_from_10_iter[i])[2])]
    plt.xticks(x, features, rotation='vertical')
    plt.title('Node2 - not interaction hubs')

# %%
for i in range(10):
    # mean feature importance accross nodes
    plt.plot(np.mean(np.concatenate((scores_from_10_iter[i][:, 0, :, 0], scores_from_10_iter[i][:, 0, :, 1]), axis=0), axis=0))
    x = [float(i) for i in range(np.shape(scores_from_10_iter[i])[2])]
    plt.xticks(x, features, rotation='vertical')
    plt.title('Accross all Nodes')

# %%
i=0
vmin = np.min(np.concatenate((scores_from_10_iter[i][:, 0, :, 0], scores_from_10_iter[i][:, 0, :, 1]), axis=1))
vmax = np.max(np.concatenate((scores_from_10_iter[i][:, 0, :, 0], scores_from_10_iter[i][:, 0, :, 1]), axis=1))
features = ['ATAC', 'CTCF', 'POL3', 'TP63', 'LSD1', 'H3K27ac', 'H3K27me3', 'H3K4me1', 'H3K4me3', 'H3K9ac']
x = [float(i+0.5) for i in range(np.shape(scores)[2])]

# %%
#plt.imshow(scores[:, 0, :, 0], cmap='hot', interpolation='nearest')
i=0
plt.pcolor(scores_from_10_iter[i][:, 0, :, 0], cmap='hot', vmin=vmin, vmax=vmax) # cmap='RdBu'
plt.xticks(x, features, rotation='vertical')
plt.xlabel('Features')
plt.ylabel('DeepLift Score')
plt.title('Node 1')
plt.colorbar()

# %%
#plt.imshow(scores[:, 0, :, 1], cmap='hot', interpolation='nearest')
i=0
plt.pcolor(scores_from_10_iter[i][:, 0, :, 1], cmap='hot', vmin=vmin, vmax=vmax) # cmap='RdBu'
plt.xticks(x, features, rotation='vertical')
plt.xlabel('Features')
plt.ylabel('DeepLift Score')
plt.title('Node 1')
plt.colorbar()

# %% [markdown]
# # with genomic locations

# %%
scores_from_10_iter =[]
for i in range(10):
    dnn_normalized = LongRangeDNN(num_features=11, use_deep_CNN=True)
    validation_data = (X_valid_normalized[:, :, :11, :], y_valid)
    dnn_normalized.train(X_train_normalized[:, :, :11, :], y_train, validation_data)
    dnn_normalized.save(contacts+'dnn_CONV_w_dist', '/users/mtaranov/LongRange3D/')
    print "Iter",i, " summary:"
    print(dnn_normalized.test(X_test_normalized[:, :, :11, :], y_test))
    print(dnn_normalized.test(X_train_normalized[:, :, :11, :], y_train))
    print(dnn_normalized.test(X_valid_normalized[:, :, :11, :], y_valid))
    
    weights='/users/mtaranov/LongRange3D/weights/'+contacts+'dnn_CONV_w_dist.weights.h5'
    json_model='/users/mtaranov/LongRange3D/models/'+contacts+'dnn_CONV_w_dist.arch.json'
    scores = dnn_normalized.deeplift(X_valid_normalized[:, :, :11, :], weights, json_model, batch_size=128)
    scores_from_10_iter.append(scores)

# %%
features = ['ATAC', 'CTCF', 'POL3', 'TP63', 'LSD1', 'H3K27ac', 'H3K27me3', 'H3K4me1', 'H3K4me3', 'H3K9ac', 'Distance']
for i in range(10):
    # mean feature importance on node 1
    plt.plot(np.mean(scores_from_10_iter[i][:, 0, :, 0], axis=0))
    x = [float(i) for i in range(np.shape(scores_from_10_iter[i])[2])]
    plt.xticks(x, features, rotation='vertical')
    plt.title('Node1 - interaction hubs')

# %%
for i in range(10):
    # mean feature importance on node 1
    plt.plot(np.mean(scores_from_10_iter[i][:, 0, :, 1], axis=0))
    x = [float(i) for i in range(np.shape(scores_from_10_iter[i])[2])]
    plt.xticks(x, features, rotation='vertical')
    plt.title('Node2 - not interaction hubs')

# %%
for i in range(10):
    # mean feature importance on node 1
    plt.plot(np.mean(np.concatenate((scores_from_10_iter[i][:, 0, :, 0], scores_from_10_iter[i][:, 0, :, 1]), axis=0), axis=0))
    x = [float(i) for i in range(np.shape(scores_from_10_iter[i])[2])]
    plt.xticks(x, features, rotation='vertical')
    plt.title('Accross all Nodes')

# %% [markdown]
# # with distance only

# %%
dnn_normalized = LongRangeDNN(num_features=1, use_deep_CNN=True)
validation_data = (X_valid_normalized[:, :, 10:, :], y_valid)
dnn_normalized.train(X_train_normalized[:, :, 10:, :], y_train, validation_data)

# %%
print(dnn_normalized.test(X_test_normalized[:, :,  10:, :], y_test))
print(dnn_normalized.test(X_train_normalized[:, :,  10:, :], y_train))

# %% [markdown]
# ## with ATAC only

# %%
dnn_normalized = LongRangeDNN(num_features=1, use_deep_CNN=True)
validation_data = (X_valid_normalized[:, :, :1, :], y_valid)
dnn_normalized.train(X_train_normalized[:, :, :1, :], y_train, validation_data)

# %%
print(dnn_normalized.test(X_test_normalized[:, :,  10:, :], y_test))
print(dnn_normalized.test(X_train_normalized[:, :,  10:, :], y_train))

# %% [markdown]
# # Print prediction

# %%
indx_train = np.load('/users/mtaranov/NN_thres5max_datasets/dist_matched/indx_train_thres_10.npy')
indx_valid = np.load('/users/mtaranov/NN_thres5max_datasets/dist_matched/indx_valid_thres_10.npy')
indx_test = np.load ('/users/mtaranov/NN_thres5max_datasets/dist_matched/indx_test_thres_10.npy')

# %%
labels_all=(np.concatenate((y_train, y_valid, y_test), axis=0)).astype(int)
preds_all=(np.concatenate((pred_probs_train, pred_probs_valid, pred_probs_test), axis=0))
indx_all=np.concatenate((indx_train, indx_valid, indx_test), axis=0)

labels_chr1 = labels_all[np.ravel(np.where(indx_all[:,2]==1))]
preds_chr1 = preds_all[np.ravel(np.where(indx_all[:,2]==1))]
indx_chr1 = indx_all[np.ravel(np.where(indx_all[:,2]==1))]

# %%
NumberOfNodes=2272
preds_chr1_2d, labels_chr1_2d = get_2D(indx_chr1, preds_chr1, labels_chr1, NumberOfNodes)
# preds_test_2d, labels_test_2d = get_2D(indx_test, preds_test, labels_test, NumberOfNodes)

# %%
# printMatrix(preds_chr1_2d, '', 1, 1, title='preds')
# printMatrix(labels_chr1_2d, '', 1, 1, title='Captures')

# %%
zoomIn_window = (400,460)
NumberOfNodes=2272
plot_prediction(change_scale(preds_chr1_2d)+change_scale(preds_chr1_2d).T, change_scale(labels_chr1_2d)+change_scale(labels_chr1_2d).T, zoomIn_window, )
